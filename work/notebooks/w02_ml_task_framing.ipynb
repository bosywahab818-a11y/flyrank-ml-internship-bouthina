# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bosywahab818-a11y/flyrank-ml-internship-bouthina/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ### My Lane as an ML Task
#
# My lane is a **Scoring** task.
#
# The goal is to assign each content page a **Refresh Opportunity Score** that helps prioritize which pages should be updated first. The score is estimated using historical performance, search metrics, and content freshness instead of assigning pages to fixed categories.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ### Target or Proxy
#
# The dataset does not include a direct "Refresh Opportunity Score", so I would create a proxy score.
#
# The proxy would combine features such as **impressions_90d**, **ctr**, **avg_position**, **content_age_days**, **days_since_last_update**, and **trend_pct**. Pages with declining traffic, older content, and lower rankings would receive higher refresh scores.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ### Success Metric
#
# I would evaluate the model using **Mean Absolute Error (MAE)** because the task predicts a numerical score.
#
# A lower MAE means the predicted refresh scores are closer to the desired target scores and provide better prioritization for the content team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### The Unit of Analysis
#
# Each row represents **one content page**.
#
# Each page includes search metrics, traffic metrics, engagement metrics, content characteristics, and freshness information that can be used to estimate its refresh opportunity.

# %%
import pandas as pd

# Construct the raw GitHub URL for the dataset
url = "https://raw.githubusercontent.com/bosywahab818-a11y/flyrank-ml-internship-bouthina/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
print("Shape:", df.shape)

df.info()
# Out:
# Shape: (30000, 44)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
# ...

# %%
print("Dataset shape:", df.shape)

important_columns = [
    "content_id",
    "impressions_90d",
    "ctr",
    "avg_position",
    "content_age_days",
    "days_since_last_update",
    "trend_direction",
    "trend_pct"
]

df[important_columns].head()
# Out:
# Dataset shape: (30000, 44)
#              content_id  impressions_90d   ctr  avg_position  \
# 0  content_304f48230142             3803  0.76          10.6
# 1  content_a1fb4e703a9e            15320  0.05          20.3
# 2  content_9aa793d4d895            12581  0.09          36.5
# 3  content_331d6c4de07b            11751  0.49           6.2
# 4  content_d99b7a2d90ca            19140  0.13          44.0
#
#    content_age_days  days_since_last_update trend_direction  trend_pct
# 0               187                      20            down      -41.4
# 1               445                      25            down      -57.7
# 2               141                      20            down      -60.9
# 3               463                      22          stable      -13.8
# 4               263                      14            down      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Why ML Beats a Fixed Rule
#
# A fixed rule cannot effectively combine many factors such as traffic, CTR, search ranking, content age, engagement, and trend direction.
#
# Machine learning can learn complex relationships between these features and produce more accurate refresh scores, helping the content team prioritize updates more effectively.

# %%
df.select_dtypes(include="number").describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %%
df[[
    "impressions_90d",
    "ctr",
    "avg_position",
    "content_age_days",
    "trend_pct"
]].describe()
# Out:
#        impressions_90d           ctr  avg_position  content_age_days  \
# count     30000.000000  30000.000000   30000.00000       30000.00000
# mean       5200.366300      0.510733      16.34238         256.16780
# std       16838.019547      3.279162      15.21679         132.70793
# min           1.000000      0.000000       0.00000          90.00000
# 25%          81.000000      0.000000       6.20000         132.00000
# 50%         731.000000      0.070000      10.80000         236.00000
# 75%        3615.250000      0.290000      22.30000         333.00000
# max      517715.000000    100.000000     245.00000         564.00000
#
#           trend_pct
# count  26612.000000
# mean      -4.785969
# std      473.861780
# min     -100.000000
# 25%      -62.600000
# 50%      -33.500000
# 75%        0.000000
# max    44900.000000

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
